# %%
import itertools
import re
import pandas as pd
import numpy as np
import os 

from script_get_de_and_summary_jupyter import *

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye124/ttof5600/32fix")
hye124_ttof5600_32fix, hye124_ttof5600_32fix_de = get_summary_hye124()
# Out:
# /home/ptruong/git/dia_sum/scripts/PXD002952/script_get_de_and_summary_jupyter.py:285: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_sample["proteinQuantity"] = df_sample["ProteinName"].map(get_protein_quantity)
# time: 21.54874062538147 s
# time: 23.581368923187256 s
# time: 21.134708404541016 s
# time: 20.038915872573853 s
# /home/ptruong/git/dia_sum/scripts/PXD002952/script_get_de_and_summary_jupyter.py:353: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df_xs = pd.concat(df_x_list, axis = 1)

# %%
hye124_ttof5600_32fix
# Out:
#   experiment_id sample_id proteins peptides
# 0     001-Pedro       [1]     1600    11992
# 1     002-Pedro       [2]     1690    12932
# 2     003-Pedro       [1]     1594    11877
# 3     005-Pedro       [1]     1555    11426

# %%
hye124_ttof5600_32fix_de
# Out:
#                                                     human_de  ecoli_de  \
# (001-Pedro_1_proteinQuantity, 002-Pedro_2_prote...       399         1
# (001-Pedro_1_proteinQuantity, 003-Pedro_1_prote...       481         0
# (001-Pedro_1_proteinQuantity, 005-Pedro_1_prote...       414         0
# (002-Pedro_2_proteinQuantity, 003-Pedro_1_prote...       408         0
# (002-Pedro_2_proteinQuantity, 005-Pedro_1_prote...       387         0
# (003-Pedro_1_proteinQuantity, 005-Pedro_1_prote...       419         0
#
#                                                     yeast_de
# (001-Pedro_1_proteinQuantity, 002-Pedro_2_prote...         0
# (001-Pedro_1_proteinQuantity, 003-Pedro_1_prote...         0
# (001-Pedro_1_proteinQuantity, 005-Pedro_1_prote...         0
# (002-Pedro_2_proteinQuantity, 003-Pedro_1_prote...        12
# (002-Pedro_2_proteinQuantity, 005-Pedro_1_prote...        12
# (003-Pedro_1_proteinQuantity, 005-Pedro_1_prote...         0

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye124/ttof5600/32fix_w_64v_library_test")
hye124_ttof5600_32fix_w_64var_specLib, hye124_ttof5600_32fix_w_64var_specLib_de = get_summary_hye124()
# Out:
# time: 20.936028718948364 s
# time: 24.134610176086426 s
# time: 21.143524885177612 s
# time: 20.38842463493347 s

# %%
hye124_ttof5600_32fix_w_64var_specLib
# Out:
#   experiment_id sample_id proteins peptides
# 0     001-Pedro       [1]     1855    10653
# 1     002-Pedro       [2]     2013    11719
# 2     003-Pedro       [1]     1871    10591
# 3     005-Pedro       [1]     1797    10073

# %%
hye124_ttof5600_32fix_w_64var_specLib_de
# Out:
#                                                     human_de  ecoli_de  \
# (001-Pedro_1_proteinQuantity, 002-Pedro_2_prote...       143         0
# (001-Pedro_1_proteinQuantity, 003-Pedro_1_prote...       331         0
# (001-Pedro_1_proteinQuantity, 005-Pedro_1_prote...       290         0
# (002-Pedro_2_proteinQuantity, 003-Pedro_1_prote...       158         0
# (002-Pedro_2_proteinQuantity, 005-Pedro_1_prote...       141         0
# (003-Pedro_1_proteinQuantity, 005-Pedro_1_prote...       288         0
#
#                                                     yeast_de
# (001-Pedro_1_proteinQuantity, 002-Pedro_2_prote...         8
# (001-Pedro_1_proteinQuantity, 003-Pedro_1_prote...         0
# (001-Pedro_1_proteinQuantity, 005-Pedro_1_prote...         1
# (002-Pedro_2_proteinQuantity, 003-Pedro_1_prote...         4
# (002-Pedro_2_proteinQuantity, 005-Pedro_1_prote...         3
# (003-Pedro_1_proteinQuantity, 005-Pedro_1_prote...         3

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye124/ttof5600/64var")
hye124_ttof5600_64var, hye124_ttof5600_64var_de = get_summary_hye124()
# Out:
# time: 43.671239376068115 s
# time: 37.32342290878296 s
# time: 42.48905324935913 s
# time: 41.44592523574829 s

# %%
hye124_ttof5600_64var
# Out:
#   experiment_id sample_id proteins peptides
# 0     007-Pedro       [1]     2411    20071
# 1     008-Pedro       [2]     2207    17671
# 2     009-Pedro       [1]     2331    19232
# 3     010-Pedro       [2]     2374    19232

# %%
hye124_ttof5600_64var_de
# Out:
#                                                     human_de  ecoli_de  \
# (007-Pedro_1_proteinQuantity, 008-Pedro_2_prote...       230         0
# (007-Pedro_1_proteinQuantity, 009-Pedro_1_prote...       569         0
# (007-Pedro_1_proteinQuantity, 010-Pedro_2_prote...       472         0
# (008-Pedro_2_proteinQuantity, 009-Pedro_1_prote...       380         0
# (008-Pedro_2_proteinQuantity, 010-Pedro_2_prote...       337         0
# (009-Pedro_1_proteinQuantity, 010-Pedro_2_prote...       530         0
#
#                                                     yeast_de
# (007-Pedro_1_proteinQuantity, 008-Pedro_2_prote...         0
# (007-Pedro_1_proteinQuantity, 009-Pedro_1_prote...         1
# (007-Pedro_1_proteinQuantity, 010-Pedro_2_prote...         0
# (008-Pedro_2_proteinQuantity, 009-Pedro_1_prote...        96
# (008-Pedro_2_proteinQuantity, 010-Pedro_2_prote...         0
# (009-Pedro_1_proteinQuantity, 010-Pedro_2_prote...         1

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye124/ttof6600/32fix")
hye124_ttof6600_32fix, hye124_ttof6600_32fix_de = get_summary_hye124()
# Out:
# time: 55.06310415267944 s
# time: 57.07259678840637 s
# time: 55.17685508728027 s
# time: 60.63970923423767 s
# time: 53.74865508079529 s
# time: 65.17827153205872 s

# %%
hye124_ttof6600_32fix
# Out:
#   experiment_id sample_id proteins peptides
# 0     002-Pedro       [-]     2758    24194
# 1     003-Pedro       [-]     2838    25215
# 2     004-Pedro       [-]     2739    23746
# 3     005-Pedro       [-]     2890    25820
# 4     006-Pedro       [-]     2753    24102
# 5     007-Pedro       [-]     2892    25524

# %%
hye124_ttof6600_32fix_de
# Out:
#                                                     human_de  ecoli_de  \
# (002-Pedro_-_proteinQuantity, 003-Pedro_-_prote...       654         0
# (002-Pedro_-_proteinQuantity, 004-Pedro_-_prote...       220         0
# (002-Pedro_-_proteinQuantity, 005-Pedro_-_prote...       366         0
# (002-Pedro_-_proteinQuantity, 006-Pedro_-_prote...       186         0
# (002-Pedro_-_proteinQuantity, 007-Pedro_-_prote...       248         0
# (003-Pedro_-_proteinQuantity, 004-Pedro_-_prote...       384         0
# (003-Pedro_-_proteinQuantity, 005-Pedro_-_prote...       581         0
# (003-Pedro_-_proteinQuantity, 006-Pedro_-_prote...       277         1
# (003-Pedro_-_proteinQuantity, 007-Pedro_-_prote...       387         0
# (004-Pedro_-_proteinQuantity, 005-Pedro_-_prote...       666         0
# (004-Pedro_-_proteinQuantity, 006-Pedro_-_prote...       700         0
# (004-Pedro_-_proteinQuantity, 007-Pedro_-_prote...       643         0
# ...

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye110/ttof6600/32fix")
hye110_ttof6600_32fix, hye110_ttof6600_32fix_de = get_summary_hye110()
# Out:
# /home/ptruong/git/dia_sum/scripts/PXD002952/script_get_de_and_summary_jupyter.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_sample["proteinQuantity"] = df_sample["ProteinName"].map(get_protein_quantity)
# time: 28.873619556427002 s
# time: 31.177311658859253 s
# time: 27.822954177856445 s
# time: 31.1245174407959 s
# time: 27.26920247077942 s
# /home/ptruong/git/dia_sum/scripts/PXD002952/script_get_de_and_summary_jupyter.py:110: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   df_xs = pd.concat(df_x_list, axis = 1)

# %%
hye110_ttof6600_32fix
# Out:
#   experiment_id sample_id proteins peptides
# 0     001-Pedro       [A]     1844    14612
# 1     002-Pedro       [B]     1857    15650
# 2     003-Pedro       [A]     1804    14310
# 3     004-Pedro       [B]     1850    15495
# 4     010-Pedro       [A]     1756    13650

# %%
hye110_ttof6600_32fix_de
# Out:
#                                                     human_de  ecoli_de  \
# (001-Pedro_A_proteinQuantity, 002-Pedro_B_prote...       408        69
# (001-Pedro_A_proteinQuantity, 003-Pedro_A_prote...       353         0
# (001-Pedro_A_proteinQuantity, 004-Pedro_B_prote...       395        71
# (001-Pedro_A_proteinQuantity, 010-Pedro_A_prote...        46         0
# (002-Pedro_B_proteinQuantity, 003-Pedro_A_prote...       210       102
# (002-Pedro_B_proteinQuantity, 004-Pedro_B_prote...       632         0
# (002-Pedro_B_proteinQuantity, 010-Pedro_A_prote...        40       114
# (003-Pedro_A_proteinQuantity, 004-Pedro_B_prote...       193       111
# (003-Pedro_A_proteinQuantity, 010-Pedro_A_prote...       187         0
# (004-Pedro_B_proteinQuantity, 010-Pedro_A_prote...        41       110
#
#                                                     yeast_de
# (001-Pedro_A_proteinQuantity, 002-Pedro_B_prote...        95
# (001-Pedro_A_proteinQuantity, 003-Pedro_A_prote...         0
# ...

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye110/ttof6600/32var")
hye110_ttof6600_32var, hye110_ttof6600_32var_de = get_summary_hye110()
# Out:
# time: 35.07282996177673 s
# time: 38.1522274017334 s
# time: 33.766634702682495 s
# time: 34.519585609436035 s
# time: 33.616631746292114 s
# time: 35.151132345199585 s

# %%
hye110_ttof6600_32var
# Out:
#   experiment_id sample_id proteins peptides
# 0     001-Pedro  [A.mzML]     2167    17297
# 1     002-Pedro  [B.mzML]     2176    18273
# 2     003-Pedro  [A.mzML]     2124    17033
# 3     004-Pedro  [B.mzML]     2091    17222
# 4     005-Pedro  [A.mzML]     2132    16955
# 5     006-Pedro  [B.mzML]     2094    17582

# %%
hye110_ttof6600_32var_de
# Out:
#                                                     human_de  ecoli_de  \
# (001-Pedro_A.mzML_proteinQuantity, 002-Pedro_B....       366         0
# (001-Pedro_A.mzML_proteinQuantity, 003-Pedro_A....       788         0
# (001-Pedro_A.mzML_proteinQuantity, 004-Pedro_B....       503         0
# (001-Pedro_A.mzML_proteinQuantity, 005-Pedro_A....       703         0
# (001-Pedro_A.mzML_proteinQuantity, 006-Pedro_B....       543         0
# (002-Pedro_B.mzML_proteinQuantity, 003-Pedro_A....       302       125
# (002-Pedro_B.mzML_proteinQuantity, 004-Pedro_B....       539         0
# (002-Pedro_B.mzML_proteinQuantity, 005-Pedro_A....       252       144
# (002-Pedro_B.mzML_proteinQuantity, 006-Pedro_B....       539         0
# (003-Pedro_A.mzML_proteinQuantity, 004-Pedro_B....       459         0
# (003-Pedro_A.mzML_proteinQuantity, 005-Pedro_A....       740         0
# (003-Pedro_A.mzML_proteinQuantity, 006-Pedro_B....       519         0
# ...

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye110/ttof6600/64fix")
hye110_ttof6600_64fix, hye110_ttof6600_64fix_de = get_summary_hye110()
# Out:
# time: 31.358431577682495 s
# time: 33.35569381713867 s
# time: 30.573335647583008 s
# time: 33.49097418785095 s
# time: 31.23229742050171 s
# time: 34.52995800971985 s

# %%
hye110_ttof6600_64fix
# Out:
#   experiment_id sample_id proteins peptides
# 0     001-Pedro  [A.mzML]     2018    15947
# 1     002-Pedro  [B.mzML]     1997    16709
# 2     003-Pedro  [A.mzML]     1954    15267
# 3     004-Pedro  [B.mzML]     1956    16395
# 4     005-Pedro  [A.mzML]     2008    15839
# 5     006-Pedro  [B.mzML]     1955    16163

# %%
hye110_ttof6600_64fix_de
# Out:
#                                                     human_de  ecoli_de  \
# (001-Pedro_A.mzML_proteinQuantity, 002-Pedro_B....       403         0
# (001-Pedro_A.mzML_proteinQuantity, 003-Pedro_A....        73         0
# (001-Pedro_A.mzML_proteinQuantity, 004-Pedro_B....       414         0
# (001-Pedro_A.mzML_proteinQuantity, 005-Pedro_A....       226         0
# (001-Pedro_A.mzML_proteinQuantity, 006-Pedro_B....       451         0
# (002-Pedro_B.mzML_proteinQuantity, 003-Pedro_A....        75       147
# (002-Pedro_B.mzML_proteinQuantity, 004-Pedro_B....       342         0
# (002-Pedro_B.mzML_proteinQuantity, 005-Pedro_A....       157       153
# (002-Pedro_B.mzML_proteinQuantity, 006-Pedro_B....       324         0
# (003-Pedro_A.mzML_proteinQuantity, 004-Pedro_B....       181         0
# (003-Pedro_A.mzML_proteinQuantity, 005-Pedro_A....       415         0
# (003-Pedro_A.mzML_proteinQuantity, 006-Pedro_B....       167         0
# ...

# %%
os.chdir("/hdd_14T/data/PXD002952/osw_res_20210303/hye110/ttof6600/64var")
hye110_ttof6600_64var, hye110_ttof6600_64var_de = get_summary_hye110()
# Out:
# time: 45.911760330200195 s
# time: 45.010289669036865 s
# time: 45.63397765159607 s
# time: 46.041316509246826 s
# time: 44.12265467643738 s
# time: 41.73828864097595 s

# %%
hye110_ttof6600_64var
# Out:
#   experiment_id sample_id proteins peptides
# 0     001-Pedro       [A]     2531    21548
# 1     002-Pedro       [B]     2385    20925
# 2     003-Pedro       [A]     2550    21542
# 3     004-Pedro       [B]     2431    21528
# 4     005-Pedro       [A]     2465    20839
# 5     006-Pedro       [B]     2294    19629

# %%
hye110_ttof6600_64var_de
# Out:
#                                                     human_de  ecoli_de  \
# (001-Pedro_A_proteinQuantity, 002-Pedro_B_prote...       555       125
# (001-Pedro_A_proteinQuantity, 003-Pedro_A_prote...       892         0
# (001-Pedro_A_proteinQuantity, 004-Pedro_B_prote...       649       122
# (001-Pedro_A_proteinQuantity, 005-Pedro_A_prote...       570         0
# (001-Pedro_A_proteinQuantity, 006-Pedro_B_prote...       432        89
# (002-Pedro_B_proteinQuantity, 003-Pedro_A_prote...       641       140
# (002-Pedro_B_proteinQuantity, 004-Pedro_B_prote...       858         0
# (002-Pedro_B_proteinQuantity, 005-Pedro_A_prote...       549       161
# (002-Pedro_B_proteinQuantity, 006-Pedro_B_prote...       573         0
# (003-Pedro_A_proteinQuantity, 004-Pedro_B_prote...       679       136
# (003-Pedro_A_proteinQuantity, 005-Pedro_A_prote...       650         0
# (003-Pedro_A_proteinQuantity, 006-Pedro_B_prote...       461        85
# ...
